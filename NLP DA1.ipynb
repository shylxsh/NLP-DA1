# %%
import nltk.corpus
# from nltk.corpus import brown
# brown.categories()

nltk.download('brown')
nltk.download('webtext')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\webtext.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# Explore Brown Corpus and find the size, tokens, categories

# %%
brown.words()
len(brown.words())
# Out:
# 1161192

# %%
from nltk.corpus import webtext
from nltk import sent_tokenize, word_tokenize

# %%
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
single_no8 = webtext.raw('singles.txt').split('\n')[8]
single_no8
# Out:
# 'ARE YOU ALONE or lost in a r/ship too, with no hope in sight? Maybe we could explore new beginnings together? Im 45 Slim/Med build, GSOH, high needs and looking for someone similar. You WONT be disappointed.'

# %%
sent_tokenize(single_no8)
# Out:
# ['ARE YOU ALONE or lost in a r/ship too, with no hope in sight?',
#  'Maybe we could explore new beginnings together?',
#  'Im 45 Slim/Med build, GSOH, high needs and looking for someone similar.',
#  'You WONT be disappointed.']

# %%
for sent in sent_tokenize(single_no8):
    print(word_tokenize(sent))
# Out:
# ['ARE', 'YOU', 'ALONE', 'or', 'lost', 'in', 'a', 'r/ship', 'too', ',', 'with', 'no', 'hope', 'in', 'sight', '?']
# ['Maybe', 'we', 'could', 'explore', 'new', 'beginnings', 'together', '?']
# ['Im', '45', 'Slim/Med', 'build', ',', 'GSOH', ',', 'high', 'needs', 'and', 'looking', 'for', 'someone', 'similar', '.']
# ['You', 'WONT', 'be', 'disappointed', '.']

# %% [markdown]
# • Find the size of word types?

# %%
len(brown.categories())
# Out:
# 15

# %% [markdown]
#  Find the size of the category “government”

# %%
len(brown.words(categories='government'))
# Out:
# 70117

# %% [markdown]
# • List the most frequent tokens

# %% [markdown]
#  Count the number of sentences

# %%
len(sent_tokenize(single_no8))
# Out:
# 4

# %% [markdown]
# Explore the corpora available in NLTK (any two)
# • Raw corpus
#
# • POS tagged
#
# • Parsed
#
# • Multilingual aligned
#
# • Spoken language
#
# • Semantic tagged

# %% [markdown]
# POS tagged

# %%
from __future__ import division
import nltk, re, pprint
from nltk import word_tokenize

# %%
from nltk.corpus import  brown
text = brown.words(categories='news')
nltk.pos_tag(text)
# Out:
# [('The', 'DT'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('Grand', 'NNP'),
#  ('Jury', 'NNP'),
#  ('said', 'VBD'),
#  ('Friday', 'NNP'),
#  ('an', 'DT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NNP'),
#  ('recent', 'JJ'),
#  ('primary', 'JJ'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'DT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'IN'),
#  ('any', 'DT'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('further', 'RB'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('term-end', 'JJ'),
#  ('presentments', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('City', 'NNP'),
#  ('Executive', 'NNP'),
#  ('Committee', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('had', 'VBD'),
#  ('over-all', 'JJ'),
#  ('charge', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('deserves', 'VBZ'),
#  ('the', 'DT'),
#  ('praise', 'NN'),
#  ('and', 'CC'),
#  ('thanks', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('City', 'NNP'),
#  ('of', 'IN'),
#  ('Atlanta', 'NNP'),
#  ("''", "''"),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('manner', 'NN'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  ('was', 'VBD'),
#  ('conducted', 'VBN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('September-October', 'NNP'),
#  ('term', 'NN'),
#  ('jury', 'NN'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('charged', 'VBN'),
#  ('by', 'IN'),
#  ('Fulton', 'NNP'),
#  ('Superior', 'NNP'),
#  ('Court', 'NNP'),
#  ('Judge', 'NNP'),
#  ('Durwood', 'NNP'),
#  ('Pye', 'NNP'),
#  ('to', 'TO'),
#  ('investigate', 'VB'),
#  ('reports', 'NNS'),
#  ('of', 'IN'),
#  ('possible', 'JJ'),
#  ('``', '``'),
#  ('irregularities', 'NNS'),
#  ("''", "''"),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('hard-fought', 'JJ'),
#  ('primary', 'NN'),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('won', 'VBN'),
#  ('by', 'IN'),
#  ('Mayor-nominate', 'NNP'),
#  ('Ivan', 'NNP'),
#  ('Allen', 'NNP'),
#  ('Jr.', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Only', 'RB'),
#  ('a', 'DT'),
#  ('relative', 'JJ'),
#  ('handful', 'NN'),
#  ('of', 'IN'),
#  ('such', 'JJ'),
#  ('reports', 'NNS'),
#  ('was', 'VBD'),
#  ('received', 'VBN'),
#  ("''", "''"),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('``', '``'),
#  ('considering', 'VBG'),
#  ('the', 'DT'),
#  ('widespread', 'JJ'),
#  ('interest', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('voters', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('size', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('city', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('did', 'VBD'),
#  ('find', 'VB'),
#  ('that', 'IN'),
#  ('many', 'JJ'),
#  ('of', 'IN'),
#  ("Georgia's", 'NNP'),
#  ('registration', 'NN'),
#  ('and', 'CC'),
#  ('election', 'NN'),
#  ('laws', 'NNS'),
#  ('``', '``'),
#  ('are', 'VBP'),
#  ('outmoded', 'VBN'),
#  ('or', 'CC'),
#  ('inadequate', 'JJ'),
#  ('and', 'CC'),
#  ('often', 'RB'),
#  ('ambiguous', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('recommended', 'VBD'),
#  ('that', 'IN'),
#  ('Fulton', 'NNP'),
#  ('legislators', 'NNS'),
#  ('act', 'VBP'),
#  ('``', '``'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('these', 'DT'),
#  ('laws', 'NNS'),
#  ('studied', 'VBD'),
#  ('and', 'CC'),
#  ('revised', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('modernizing', 'NN'),
#  ('and', 'CC'),
#  ('improving', 'VBG'),
#  ('them', 'PRP'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'JJ'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('among', 'IN'),
#  ('them', 'PRP'),
#  ('the', 'DT'),
#  ('Atlanta', 'NNP'),
#  ('and', 'CC'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('purchasing', 'NN'),
#  ('departments', 'NNS'),
#  ('which', 'WDT'),
#  ('it', 'PRP'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('are', 'VBP'),
#  ('well', 'RB'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VBP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'DT'),
#  ('governments', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Merger', 'NNP'),
#  ('proposed', 'VBD'),
#  ('However', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('believes', 'VBZ'),
#  ('``', '``'),
#  ('these', 'DT'),
#  ('two', 'CD'),
#  ('offices', 'NNS'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('combined', 'VBN'),
#  ('to', 'TO'),
#  ('achieve', 'VB'),
#  ('greater', 'JJR'),
#  ('efficiency', 'NN'),
#  ('and', 'CC'),
#  ('reduce', 'VB'),
#  ('the', 'DT'),
#  ('cost', 'NN'),
#  ('of', 'IN'),
#  ('administration', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('City', 'NNP'),
#  ('Purchasing', 'NNP'),
#  ('Department', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('``', '``'),
#  ('is', 'VBZ'),
#  ('lacking', 'VBG'),
#  ('in', 'IN'),
#  ('experienced', 'JJ'),
#  ('clerical', 'JJ'),
#  ('personnel', 'NNS'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('result', 'NN'),
#  ('of', 'IN'),
#  ('city', 'NN'),
#  ('personnel', 'NNS'),
#  ('policies', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('urged', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('``', '``'),
#  ('take', 'VB'),
#  ('steps', 'NNS'),
#  ('to', 'TO'),
#  ('remedy', 'VB'),
#  ("''", "''"),
#  ('this', 'DT'),
#  ('problem', 'NN'),
#  ('.', '.'),
#  ('Implementation', 'NN'),
#  ('of', 'IN'),
#  ("Georgia's", 'NNP'),
#  ('automobile', 'NN'),
#  ('title', 'NN'),
#  ('law', 'NN'),
#  ('was', 'VBD'),
#  ('also', 'RB'),
#  ('recommended', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('outgoing', 'JJ'),
#  ('jury', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('urged', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('Legislature', 'NNP'),
#  ('``', '``'),
#  ('provide', 'VB'),
#  ('enabling', 'VBG'),
#  ('funds', 'NNS'),
#  ('and', 'CC'),
#  ('re-set', 'VB'),
#  ('the', 'DT'),
#  ('effective', 'JJ'),
#  ('date', 'NN'),
#  ('so', 'RB'),
#  ('that', 'IN'),
#  ('an', 'DT'),
#  ('orderly', 'JJ'),
#  ('implementation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('law', 'NN'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('effected', 'VBN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('took', 'VBD'),
#  ('a', 'DT'),
#  ('swipe', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Welfare', 'NNP'),
#  ("Department's", 'NNP'),
#  ('handling', 'NN'),
#  ('of', 'IN'),
#  ('federal', 'JJ'),
#  ('funds', 'NNS'),
#  ('granted', 'VBN'),
#  ('for', 'IN'),
#  ('child', 'NN'),
#  ('welfare', 'NN'),
#  ('services', 'NNS'),
#  ('in', 'IN'),
#  ('foster', 'JJ'),
#  ('homes', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('major', 'JJ'),
#  ('items', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('general', 'JJ'),
#  ('assistance', 'NN'),
#  ('program', 'NN'),
#  ("''", "''"),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Welfare', 'NNP'),
#  ('Department', 'NNP'),
#  ('``', '``'),
#  ('has', 'VBZ'),
#  ('seen', 'VBN'),
#  ('fit', 'NN'),
#  ('to', 'TO'),
#  ('distribute', 'VB'),
#  ('these', 'DT'),
#  ('funds', 'NNS'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('welfare', 'NN'),
#  ('departments', 'NNS'),
#  ('of', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('counties', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('exception', 'NN'),
#  ('of', 'IN'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('receives', 'VBZ'),
#  ('none', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('money', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jurors', 'NNS'),
#  ('said', 'VBD'),
#  ('they', 'PRP'),
#  ('realize', 'VBP'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('proportionate', 'JJ'),
#  ('distribution', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('funds', 'NNS'),
#  ('might', 'MD'),
#  ('disable', 'VB'),
#  ('this', 'DT'),
#  ('program', 'NN'),
#  ('in', 'IN'),
#  ('our', 'PRP$'),
#  ('less', 'CC'),
#  ('populous', 'JJ'),
#  ('counties', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Nevertheless', 'NNP'),
#  (',', ','),
#  ('``', '``'),
#  ('we', 'PRP'),
#  ('feel', 'VBP'),
#  ('that', 'IN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('future', 'JJ'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('should', 'MD'),
#  ('receive', 'VB'),
#  ('some', 'DT'),
#  ('portion', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('available', 'JJ'),
#  ('funds', 'NNS'),
#  ("''", "''"),
#  (',', ','),
#  ('the', 'DT'),
#  ('jurors', 'NNS'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Failure', 'NN'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('this', 'DT'),
#  ('will', 'MD'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('place', 'VB'),
#  ('a', 'DT'),
#  ('disproportionate', 'NN'),
#  ('burden', 'NN'),
#  ("''", "''"),
#  ('on', 'IN'),
#  ('Fulton', 'NNP'),
#  ('taxpayers', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('also', 'RB'),
#  ('commented', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Fulton', 'NNP'),
#  ("ordinary's", 'MD'),
#  ('court', 'NN'),
#  ('which', 'WDT'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('under', 'IN'),
#  ('fire', 'NN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('appointment', 'NN'),
#  ('of', 'IN'),
#  ('appraisers', 'NNS'),
#  (',', ','),
#  ('guardians', 'NNS'),
#  ('and', 'CC'),
#  ('administrators', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('awarding', 'NN'),
#  ('of', 'IN'),
#  ('fees', 'NNS'),
#  ('and', 'CC'),
#  ('compensation', 'NN'),
#  ('.', '.'),
#  ('Wards', 'NNS'),
#  ('protected', 'VBD'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('found', 'VBD'),
#  ('the', 'DT'),
#  ('court', 'NN'),
#  ('``', '``'),
#  ('has', 'VBZ'),
#  ('incorporated', 'VBN'),
#  ('into', 'IN'),
#  ('its', 'PRP$'),
#  ('operating', 'NN'),
#  ('procedures', 'VBZ'),
#  ('the', 'DT'),
#  ('recommendations', 'NNS'),
#  ("''", "''"),
#  ('of', 'IN'),
#  ('two', 'CD'),
#  ('previous', 'JJ'),
#  ('grand', 'JJ'),
#  ('juries', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Atlanta', 'NNP'),
#  ('Bar', 'NNP'),
#  ('Association', 'NNP'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('interim', 'JJ'),
#  ('citizens', 'NNS'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('These', 'DT'),
#  ('actions', 'NNS'),
#  ('should', 'MD'),
#  ('serve', 'VB'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('in', 'IN'),
#  ('fact', 'NN'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('effect', 'NN'),
#  ('the', 'DT'),
#  ("court's", 'NN'),
#  ('wards', 'NNS'),
#  ('from', 'IN'),
#  ('undue', 'JJ'),
#  ('costs', 'NNS'),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('appointed', 'VBN'),
#  ('and', 'CC'),
#  ('elected', 'VBN'),
#  ('servants', 'NNS'),
#  ('from', 'IN'),
#  ('unmeritorious', 'JJ'),
#  ('criticisms', 'NNS'),
#  ("''", "''"),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Regarding', 'VBG'),
#  ("Atlanta's", 'NNP'),
#  ('new', 'JJ'),
#  ('multi-million-dollar', 'JJ'),
#  ('airport', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('recommended', 'VBD'),
#  ('``', '``'),
#  ('that', 'IN'),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('management', 'NN'),
#  ('takes', 'VBZ'),
#  ('charge', 'NN'),
#  ('Jan.', 'NNP'),
#  ('1', 'CD'),
#  ('the', 'DT'),
#  ('airport', 'NN'),
#  ('be', 'VB'),
#  ('operated', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('manner', 'NN'),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('eliminate', 'VB'),
#  ('political', 'JJ'),
#  ('influences', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('elaborate', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('added', 'VBD'),
#  ('that', 'IN'),
#  ('``', '``'),
#  ('there', 'EX'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('periodic', 'JJ'),
#  ('surveillance', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('pricing', 'NN'),
#  ('practices', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('concessionaires', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('purpose', 'NN'),
#  ('of', 'IN'),
#  ('keeping', 'VBG'),
#  ('the', 'DT'),
#  ('prices', 'NNS'),
#  ('reasonable', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Ask', 'NNP'),
#  ('jail', 'NN'),
#  ('deputies', 'NNS'),
#  ('On', 'IN'),
#  ('other', 'JJ'),
#  ('matters', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('recommended', 'VBD'),
#  ('that', 'IN'),
#  (':', ':'),
#  ('(', '('),
#  ('1', 'CD'),
#  (')', ')'),
#  ('Four', 'CD'),
#  ('additional', 'JJ'),
#  ('deputies', 'NNS'),
#  ('be', 'VB'),
#  ('employed', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('Jail', 'NNP'),
#  ('and', 'CC'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('doctor', 'NN'),
#  (',', ','),
#  ('medical', 'JJ'),
#  ('intern', 'NN'),
#  ('or', 'CC'),
#  ('extern', 'JJ'),
#  ('be', 'VB'),
#  ('employed', 'VBN'),
#  ('for', 'IN'),
#  ('night', 'NN'),
#  ('and', 'CC'),
#  ('weekend', 'NN'),
#  ('duty', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('jail', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('(', '('),
#  ('2', 'CD'),
#  (')', ')'),
#  ('Fulton', 'NNP'),
#  ('legislators', 'VBZ'),
#  ('``', '``'),
#  ('work', 'NN'),
#  ('with', 'IN'),
#  ('city', 'NN'),
#  ('officials', 'NNS'),
#  ('to', 'TO'),
#  ('pass', 'VB'),
#  ('enabling', 'VBG'),
#  ('legislation', 'NN'),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('permit', 'VB'),
#  ('the', 'DT'),
#  ('establishment', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('fair', 'JJ'),
#  ('and', 'CC'),
#  ('equitable', 'JJ'),
#  ("''", "''"),
#  ('pension', 'NN'),
#  ('plan', 'NN'),
#  ('for', 'IN'),
#  ('city', 'NN'),
#  ('employes', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('jury', 'NN'),
#  ('praised', 'VBD'),
#  ('the', 'DT'),
#  ('administration', 'NN'),
#  ('and', 'CC'),
#  ('operation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Atlanta', 'NNP'),
#  ('Police', 'NNP'),
#  ('Department', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Fulton', 'NNP'),
#  ('Tax', 'NNP'),
#  ("Commissioner's", 'NNP'),
#  ('Office', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Bellwood', 'NNP'),
#  ('and', 'CC'),
#  ('Alpharetta', 'NNP'),
#  ('prison', 'NN'),
#  ('farms', 'NNS'),
#  (',', ','),
#  ('Grady', 'NNP'),
#  ('Hospital', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Fulton', 'NNP'),
#  ('Health', 'NNP'),
#  ('Department', 'NNP'),
#  ('.', '.'),
#  ('Mayor', 'NNP'),
#  ('William', 'NNP'),
#  ('B.', 'NNP'),
#  ('Hartsfield', 'NNP'),
#  ('filed', 'VBD'),
#  ('suit', 'NN'),
#  ('for', 'IN'),
#  ('divorce', 'NN'),
#  ('from', 'IN'),
#  ('his', 'PRP$'),
#  ('wife', 'NN'),
#  (',', ','),
#  ('Pearl', 'NNP'),
#  ('Williams', 'NNP'),
#  ('Hartsfield', 'NNP'),
#  (',', ','),
#  ('in', 'IN'),
#  ('Fulton', 'NNP'),
#  ('Superior', 'NNP'),
#  ('Court', 'NNP'),
#  ('Friday', 'NNP'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('petition', 'NN'),
#  ('charged', 'VBN'),
#  ('mental', 'JJ'),
#  ('cruelty', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('couple', 'NN'),
#  ('was', 'VBD'),
#  ('married', 'VBN'),
#  ('Aug.', 'NNP'),
#  ('2', 'CD'),
#  (',', ','),
#  ('1913', 'CD'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('son', 'NN'),
#  (',', ','),
#  ('William', 'NNP'),
#  ('Berry', 'NNP'),
#  ('Jr.', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('daughter', 'NN'),
#  (',', ','),
#  ('Mrs.', 'NNP'),
#  ('J.', 'NNP'),
#  ('M.', 'NNP'),
#  ('Cheshire', 'NNP'),
#  ('of', 'IN'),
#  ('Griffin', 'NNP'),
#  ('.', '.'),
#  ('Attorneys', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('mayor', 'NN'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('an', 'DT'),
#  ('amicable', 'JJ'),
#  ('property', 'NN'),
#  ('settlement', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('agreed', 'VBN'),
#  ('upon', 'IN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('petition', 'NN'),
#  ('listed', 'VBD'),
#  ('the', 'DT'),
#  ("mayor's", 'JJ'),
#  ('occupation', 'NN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('attorney', 'NN'),
#  ("''", "''"),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('age', 'NN'),
#  ('as', 'IN'),
#  ('71', 'CD'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('listed', 'VBD'),
#  ('his', 'PRP$'),
#  ("wife's", 'JJ'),
#  ('age', 'NN'),
#  ('as', 'IN'),
#  ('74', 'CD'),
#  ('and', 'CC'),
#  ('place', 'NN'),
#  ('of', 'IN'),
#  ('birth', 'NN'),
#  ('as', 'IN'),
#  ('Opelika', 'NNP'),
#  (',', ','),
#  ('Ala.', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('petition', 'NN'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('couple', 'NN'),
#  ('has', 'VBZ'),
#  ('not', 'RB'),
#  ('lived', 'VBN'),
#  ('together', 'RB'),
#  ('as', 'IN'),
#  ('man', 'NN'),
#  ('and', 'CC'),
#  ('wife', 'NN'),
#  ('for', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Hartsfield', 'NNP'),
#  ('home', 'NN'),
#  ('is', 'VBZ'),
#  ('at', 'IN'),
#  ('637', 'CD'),
#  ('E.', 'NNP'),
#  ('Pelham', 'NNP'),
#  ('Rd.', 'NNP'),
#  ('Aj', 'NNP'),
#  ('.', '.'),
#  ('Henry', 'NNP'),
#  ('L.', 'NNP'),
#  ('Bowden', 'NNP'),
#  ('was', 'VBD'),
#  ('listed', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('petition', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ("mayor's", 'NN'),
#  ('attorney', 'NN'),
#  ('.', '.'),
#  ('Hartsfield', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('mayor', 'NN'),
#  ('of', 'IN'),
#  ('Atlanta', 'NNP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('exception', 'NN'),
#  ('of', 'IN'),
#  ('one', 'CD'),
#  ('brief', 'NN'),
#  ('interlude', 'NN'),
#  (',', ','),
#  ('since', 'IN'),
#  ('1937', 'CD'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('political', 'JJ'),
#  ('career', 'NN'),
#  ('goes', 'VBZ'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('election', 'NN'),
#  ('to', 'TO'),
#  ('city', 'NN'),
#  ('council', 'NN'),
#  ('in', 'IN'),
#  ('1923', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ("mayor's", 'JJ'),
#  ('present', 'JJ'),
#  ('term', 'NN'),
#  ('of', 'IN'),
#  ('office', 'NN'),
#  ('expires', 'VBZ'),
#  ('Jan.', 'NNP'),
#  ('1', 'CD'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('succeeded', 'VBN'),
#  ('by', 'IN'),
#  ('Ivan', 'NNP'),
#  ('Allen', 'NNP'),
#  ('Jr.', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('became', 'VBD'),
#  ('a', 'DT'),
#  ('candidate', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Sept.', 'NNP'),
#  ('13', 'CD'),
#  ('primary', 'NN'),
#  ('after', 'IN'),
#  ('Mayor', 'NNP'),
#  ('Hartsfield', 'NNP'),
#  ('announced', 'VBD'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('run', 'VB'),
#  ('for', 'IN'),
#  ('reelection', 'NN'),
#  ('.', '.'),
#  ('Georgia', 'NNP'),
#  ('Republicans', 'NNPS'),
#  ('are', 'VBP'),
#  ('getting', 'VBG'),
#  ('strong', 'JJ'),
#  ('encouragement', 'NN'),
#  ('to', 'TO'),
#  ('enter', 'VB'),
#  ('a', 'DT'),
#  ('candidate', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('1962', 'CD'),
#  ("governor's", 'NN'),
#  ...]

# %% [markdown]
# Printing words and tagged words

# %%
nltk.download('universal_tagset')
print(nltk.corpus.brown.tagged_words())
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# [('The', 'DET'), ('Fulton', 'NOUN'), ...]

# %%
import nltk. corpus
print(str(nltk. corpus. brown).replace( '\\\\','/' ) )
nltk. corpus. brown. fileids()
from nltk.corpus import brown
from nltk.corpus import indian
from nltk.corpus import ieer

indian.fileids()
ieer.fileids()
print(brown.raw('caø7'))
print(brown.tagged_words())
docs=ieer.parsed_docs('APW 19980429')
print(docs[0])
print(docs[0].docno)
print(docs[0].doctype)
print(docs[0].date_time)
print(docs[0].headline)
print(docs[0].text)
nltk.corpus.indian.words('hindi.pos')
# Out:
# <CategorizedTaggedCorpusReader in 'C:/Users/shyle_dwx0bd9/AppData/Roaming/nltk_data/corpora/brown'>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\anaconda3\lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource indian not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('indian')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/indian.zip/indian/
#
#   Searched in:
#     - 'C:\\Users\\shyle_dwx0bd9/nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Input In [35], in <cell line: 8>()
#       5 from nltk.corpus import indian
#       6 from nltk.corpus import ieer
# ----> 8 indian.fileids()
#       9 ieer.fileids()
#      10 print(brown.raw('caø7'))
#
# File ~\anaconda3\lib\site-packages\nltk\corpus\util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File ~\anaconda3\lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~\anaconda3\lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~\anaconda3\lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource indian not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('indian')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/indian
#
#   Searched in:
#     - 'C:\\Users\\shyle_dwx0bd9/nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\shyle_dwx0bd9\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %% [markdown]
# Printing the tag and its frequencies

# %%
text = brown.words(categories='news')
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %% [markdown]
# Displaying the frequency of every word in category news in brown as a graph

# %%
single_no8 = brown.words(categories='news')
fd = nltk.FreqDist(single_no8)
fd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# 2.Parsed
#
#
# Program for creating trees from the given grammer

# %%
grammar = nltk.CFG.fromstring("""
    S -> NP VP
    PP -> P NP
    NP -> Det N | Det N PP | 'I'
    VP -> V NP | VP PP
    Det -> 'an' | 'my'
    N -> 'elephant' | 'pajamas'
    V -> 'shot'
    P -> 'in'
    """)
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(grammar)
for tree in parser.parse(sent):
     print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# Parsing with context free grammer

# %%
grammar1 = nltk.CFG.fromstring("""
  S -> NP VP
  VP -> V NP | V NP PP
  PP -> P NP
  V -> "saw" | "ate" | "walked"
  NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
  Det -> "a" | "an" | "the" | "my"
  N -> "man" | "dog" | "cat" | "telescope" | "park"
  P -> "in" | "on" | "by" | "with"
  """)
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
    print(tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %%
groucho_dep_grammar = nltk.DependencyGrammar.fromstring("""
    'shot' -> 'I' | 'elephant' | 'in'
    'elephant' -> 'an' | 'in'
    'in' -> 'pajamas'
    'pajamas' -> 'my'
    """)
print(groucho_dep_grammar)           #dependecy grammar
pdp = nltk.ProjectiveDependencyParser(groucho_dep_grammar)
sent = 'I shot an elephant in my pajamas'.split()
trees = pdp.parse(sent)
for tree in trees:
     print(tree)
# Out:
# Dependency grammar with 7 productions
#   'shot' -> 'I'
#   'shot' -> 'elephant'
#   'shot' -> 'in'
#   'elephant' -> 'an'
#   'elephant' -> 'in'
#   'in' -> 'pajamas'
#   'pajamas' -> 'my'
# (shot I (elephant an (in (pajamas my))))
# (shot I (elephant an) (in (pajamas my)))

# %% [markdown]
# Create a text corpus with a minimum of 200 words (unique content). Implement the
# following text processing (05 Marks)
#
# • Word segmentation
#
# • Sentence segmentation
#
# • Convert to Lowercase
#
# • Stop words removal
#
# • Stemming
#
# • Lemmatization
#
# • Part of speech tagger
#
# Word segmentation

# %%
from nltk import sent_tokenize, word_tokenize
para = "India is a secular democracy. This means that all religions are equally respected, and every person is free to follow any religion they want. India is the largest democracy in the world. People here have all basic human rights. The national heritage animal of India is an Indian Elephant. The national river of India is the Ganges. The Ganges is the sacred Hindu river, which is so sacred that it is believed to wash the sins of people away. The highest civilian award in India is the Bharat Ratna, which means ‘jewel of India’. The most prominent personalities of India who serve with excellency is their field of work with dedication, and hard work earns this award. The Param Vir Chakra is India’s highest military decoration awarded for displaying bravery. The soldiers who have their life online to protect the citizens are the heroes of India. The first prime minister of India was Pandit Jawaharlal Nehru, also called as Pandit Nehru or Chacha Nehru. The first President of India was Dr. Rajendra Prasad by the constituent assembly. He was a member of the INC (Indian National Congress), and he was a scholar. Mohandas Karamchand Gandhi, lovingly known as Bapujii or Mahatma Gandhi, is the Father of our Nation. He is the most recognized figure worldwide, best known for his contribution to the independence of the country by non-violence. Rabindranath Tagore won the Nobel Prize in Literature in the year 1913, and he is one of the most eminent personalities in India."
word_seg=word_tokenize(para)
print(word_seg)
# Out:
# ['India', 'is', 'a', 'secular', 'democracy', '.', 'This', 'means', 'that', 'all', 'religions', 'are', 'equally', 'respected', ',', 'and', 'every', 'person', 'is', 'free', 'to', 'follow', 'any', 'religion', 'they', 'want', '.', 'India', 'is', 'the', 'largest', 'democracy', 'in', 'the', 'world', '.', 'People', 'here', 'have', 'all', 'basic', 'human', 'rights', '.', 'The', 'national', 'heritage', 'animal', 'of', 'India', 'is', 'an', 'Indian', 'Elephant', '.', 'The', 'national', 'river', 'of', 'India', 'is', 'the', 'Ganges', '.', 'The', 'Ganges', 'is', 'the', 'sacred', 'Hindu', 'river', ',', 'which', 'is', 'so', 'sacred', 'that', 'it', 'is', 'believed', 'to', 'wash', 'the', 'sins', 'of', 'people', 'away', '.', 'The', 'highest', 'civilian', 'award', 'in', 'India', 'is', 'the', 'Bharat', 'Ratna', ',', 'which', 'means', '‘', 'jewel', 'of', 'India', '’', '.', 'The', 'most', 'prominent', 'personalities', 'of', 'India', 'who', 'serve', 'with', 'excellency', 'is', 'their', 'field', 'of', 'work', 'with', 'dedication', ',', 'and', 'hard', 'work', 'earns', 'this', 'award', '.', 'The', 'Param', 'Vir', 'Chakra', 'is', 'India', '’', 's', 'highest', 'military', 'decoration', 'awarded', 'for', 'displaying', 'bravery', '.', 'The', 'soldiers', 'who', 'have', 'their', 'life', 'online', 'to', 'protect', 'the', 'citizens', 'are', 'the', 'heroes', 'of', 'India', '.', 'The', 'first', 'prime', 'minister', 'of', 'India', 'was', 'Pandit', 'Jawaharlal', 'Nehru', ',', 'also', 'called', 'as', 'Pandit', 'Nehru', 'or', 'Chacha', 'Nehru', '.', 'The', 'first', 'President', 'of', 'India', 'was', 'Dr.', 'Rajendra', 'Prasad', 'by', 'the', 'constituent', 'assembly', '.', 'He', 'was', 'a', 'member', 'of', 'the', 'INC', '(', 'Indian', 'National', 'Congress', ')', ',', 'and', 'he', 'was', 'a', 'scholar', '.', 'Mohandas', 'Karamchand', 'Gandhi', ',', 'lovingly', 'known', 'as', 'Bapujii', 'or', 'Mahatma', 'Gandhi', ',', 'is', 'the', 'Father', 'of', 'our', 'Nation', '.', 'He', 'is', 'the', 'most', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'for', 'his', 'contribution', 'to', 'the', 'independence', 'of', 'the', 'country', 'by', 'non-violence', '.', 'Rabindranath', 'Tagore', 'won', 'the', 'Nobel', 'Prize', 'in', 'Literature', 'in', 'the', 'year', '1913', ',', 'and', 'he', 'is', 'one', 'of', 'the', 'most', 'eminent', 'personalities', 'in', 'India', '.']

# %% [markdown]
# Segmentation of Sentence

# %%
sent_tokenize(para)
# Out:
# ['India is a secular democracy.',
#  'This means that all religions are equally respected, and every person is free to follow any religion they want.',
#  'India is the largest democracy in the world.',
#  'People here have all basic human rights.',
#  'The national heritage animal of India is an Indian Elephant.',
#  'The national river of India is the Ganges.',
#  'The Ganges is the sacred Hindu river, which is so sacred that it is believed to wash the sins of people away.',
#  'The highest civilian award in India is the Bharat Ratna, which means ‘jewel of India’.',
#  'The most prominent personalities of India who serve with excellency is their field of work with dedication, and hard work earns this award.',
#  'The Param Vir Chakra is India’s highest military decoration awarded for displaying bravery.',
#  'The soldiers who have their life online to protect the citizens are the heroes of India.',
#  'The first prime minister of India was Pandit Jawaharlal Nehru, also called as Pandit Nehru or Chacha Nehru.',
#  'The first President of India was Dr. Rajendra Prasad by the constituent assembly.',
#  'He was a member of the INC (Indian National Congress), and he was a scholar.',
#  'Mohandas Karamchand Gandhi, lovingly known as Bapujii or Mahatma Gandhi, is the Father of our Nation.',
#  'He is the most recognized figure worldwide, best known for his contribution to the independence of the country by non-violence.',
#  'Rabindranath Tagore won the Nobel Prize in Literature in the year 1913, and he is one of the most eminent personalities in India.']

# %% [markdown]
# convert to lowercase

# %%
word_seg_lower=[]
for i in word_seg:
     k=i.lower()
     word_seg_lower.append(k)
print(word_seg_lower)       #word segmentation in lower case
sent_seg_lower=[]
for i in sent_tokenize(para):
     l=i.lower()
     sent_seg_lower.append(l)
print(sent_seg_lower)
# Out:
# ['india', 'is', 'a', 'secular', 'democracy', '.', 'this', 'means', 'that', 'all', 'religions', 'are', 'equally', 'respected', ',', 'and', 'every', 'person', 'is', 'free', 'to', 'follow', 'any', 'religion', 'they', 'want', '.', 'india', 'is', 'the', 'largest', 'democracy', 'in', 'the', 'world', '.', 'people', 'here', 'have', 'all', 'basic', 'human', 'rights', '.', 'the', 'national', 'heritage', 'animal', 'of', 'india', 'is', 'an', 'indian', 'elephant', '.', 'the', 'national', 'river', 'of', 'india', 'is', 'the', 'ganges', '.', 'the', 'ganges', 'is', 'the', 'sacred', 'hindu', 'river', ',', 'which', 'is', 'so', 'sacred', 'that', 'it', 'is', 'believed', 'to', 'wash', 'the', 'sins', 'of', 'people', 'away', '.', 'the', 'highest', 'civilian', 'award', 'in', 'india', 'is', 'the', 'bharat', 'ratna', ',', 'which', 'means', '‘', 'jewel', 'of', 'india', '’', '.', 'the', 'most', 'prominent', 'personalities', 'of', 'india', 'who', 'serve', 'with', 'excellency', 'is', 'their', 'field', 'of', 'work', 'with', 'dedication', ',', 'and', 'hard', 'work', 'earns', 'this', 'award', '.', 'the', 'param', 'vir', 'chakra', 'is', 'india', '’', 's', 'highest', 'military', 'decoration', 'awarded', 'for', 'displaying', 'bravery', '.', 'the', 'soldiers', 'who', 'have', 'their', 'life', 'online', 'to', 'protect', 'the', 'citizens', 'are', 'the', 'heroes', 'of', 'india', '.', 'the', 'first', 'prime', 'minister', 'of', 'india', 'was', 'pandit', 'jawaharlal', 'nehru', ',', 'also', 'called', 'as', 'pandit', 'nehru', 'or', 'chacha', 'nehru', '.', 'the', 'first', 'president', 'of', 'india', 'was', 'dr.', 'rajendra', 'prasad', 'by', 'the', 'constituent', 'assembly', '.', 'he', 'was', 'a', 'member', 'of', 'the', 'inc', '(', 'indian', 'national', 'congress', ')', ',', 'and', 'he', 'was', 'a', 'scholar', '.', 'mohandas', 'karamchand', 'gandhi', ',', 'lovingly', 'known', 'as', 'bapujii', 'or', 'mahatma', 'gandhi', ',', 'is', 'the', 'father', 'of', 'our', 'nation', '.', 'he', 'is', 'the', 'most', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'for', 'his', 'contribution', 'to', 'the', 'independence', 'of', 'the', 'country', 'by', 'non-violence', '.', 'rabindranath', 'tagore', 'won', 'the', 'nobel', 'prize', 'in', 'literature', 'in', 'the', 'year', '1913', ',', 'and', 'he', 'is', 'one', 'of', 'the', 'most', 'eminent', 'personalities', 'in', 'india', '.']
# ['india is a secular democracy.', 'this means that all religions are equally respected, and every person is free to follow any religion they want.', 'india is the largest democracy in the world.', 'people here have all basic human rights.', 'the national heritage animal of india is an indian elephant.', 'the national river of india is the ganges.', 'the ganges is the sacred hindu river, which is so sacred that it is believed to wash the sins of people away.', 'the highest civilian award in india is the bharat ratna, which means ‘jewel of india’.', 'the most prominent personalities of india who serve with excellency is their field of work with dedication, and hard work earns this award.', 'the param vir chakra is india’s highest military decoration awarded for displaying bravery.', 'the soldiers who have their life online to protect the citizens are the heroes of india.', 'the first prime minister of india was pandit jawaharlal nehru, also called as pandit nehru or chacha nehru.', 'the first president of india was dr. rajendra prasad by the constituent assembly.', 'he was a member of the inc (indian national congress), and he was a scholar.', 'mohandas karamchand gandhi, lovingly known as bapujii or mahatma gandhi, is the father of our nation.', 'he is the most recognized figure worldwide, best known for his contribution to the independence of the country by non-violence.', 'rabindranath tagore won the nobel prize in literature in the year 1913, and he is one of the most eminent personalities in india.']

# %% [markdown]
# stop words removal

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
stop_words = set(stopwords.words('english'))
print(stop_words)
word_tokens = word_tokenize(para)
para_wo_sw = [w for w in word_tokens if not w.lower() in stop_words]
#para_wo_sw = []
 
for w in word_tokens:         #stop words removal
    if w not in stop_words:
        para_wo_sw.append(w)   
 
print(word_tokens)          #word tokenization
print(para_wo_sw)
# Out:
# {'yourself', 'doesn', 'whom', 'own', 'theirs', 'further', 'was', 'too', 'at', 'y', "you've", 'it', 'what', 'for', 'ours', 'our', 'your', 'on', 'now', 'be', 'where', 't', 'ma', 'my', 'them', 'those', 'than', 'after', "weren't", 'yourselves', 'here', 'or', 'me', 'how', 'a', "isn't", 'to', 'by', 'weren', 'yours', 'wasn', 'as', 'most', 'before', "mustn't", 'had', 'some', 'they', 'am', 'not', 'but', 'with', "should've", 'above', 'herself', "aren't", 'needn', 'then', 'there', 'no', 'and', 'same', 's', "wasn't", 'from', 'who', 'until', 'should', 'an', 've', 'll', 'were', "hasn't", 'mustn', 'during', 'all', 'of', 'that', "you'll", 'himself', "it's", 'through', 'these', 'his', 'she', 'you', "mightn't", 'i', 'is', 'more', "needn't", 're', "won't", 'between', "haven't", 'against', 'can', 'nor', 'isn', 'its', 'have', 'itself', 'any', 'only', "shouldn't", 'does', 'do', 'below', "that'll", 'while', 'down', 'again', 'few', 'd', "hadn't", 'won', 'very', 'over', 'hasn', 'this', 'both', 'once', 'her', 'so', 'him', 'themselves', 'each', 'he', 'because', 'has', 'about', 'ain', "wouldn't", 'been', 'couldn', 'hadn', 'shan', 'aren', "you'd", "don't", "shan't", 'hers', 'are', 'doing', 'o', "doesn't", 'why', 'ourselves', 'myself', 'having', 'such', 'shouldn', 'the', 'in', 'didn', 'will', "she's", 'which', 'wouldn', "you're", 'mightn', 'their', 'haven', 'when', 'other', 'did', 'm', 'out', 'we', 'off', 'being', "didn't", "couldn't", 'into', 'under', 'don', 'if', 'up', 'just'}
# ['India', 'is', 'a', 'secular', 'democracy', '.', 'This', 'means', 'that', 'all', 'religions', 'are', 'equally', 'respected', ',', 'and', 'every', 'person', 'is', 'free', 'to', 'follow', 'any', 'religion', 'they', 'want', '.', 'India', 'is', 'the', 'largest', 'democracy', 'in', 'the', 'world', '.', 'People', 'here', 'have', 'all', 'basic', 'human', 'rights', '.', 'The', 'national', 'heritage', 'animal', 'of', 'India', 'is', 'an', 'Indian', 'Elephant', '.', 'The', 'national', 'river', 'of', 'India', 'is', 'the', 'Ganges', '.', 'The', 'Ganges', 'is', 'the', 'sacred', 'Hindu', 'river', ',', 'which', 'is', 'so', 'sacred', 'that', 'it', 'is', 'believed', 'to', 'wash', 'the', 'sins', 'of', 'people', 'away', '.', 'The', 'highest', 'civilian', 'award', 'in', 'India', 'is', 'the', 'Bharat', 'Ratna', ',', 'which', 'means', '‘', 'jewel', 'of', 'India', '’', '.', 'The', 'most', 'prominent', 'personalities', 'of', 'India', 'who', 'serve', 'with', 'excellency', 'is', 'their', 'field', 'of', 'work', 'with', 'dedication', ',', 'and', 'hard', 'work', 'earns', 'this', 'award', '.', 'The', 'Param', 'Vir', 'Chakra', 'is', 'India', '’', 's', 'highest', 'military', 'decoration', 'awarded', 'for', 'displaying', 'bravery', '.', 'The', 'soldiers', 'who', 'have', 'their', 'life', 'online', 'to', 'protect', 'the', 'citizens', 'are', 'the', 'heroes', 'of', 'India', '.', 'The', 'first', 'prime', 'minister', 'of', 'India', 'was', 'Pandit', 'Jawaharlal', 'Nehru', ',', 'also', 'called', 'as', 'Pandit', 'Nehru', 'or', 'Chacha', 'Nehru', '.', 'The', 'first', 'President', 'of', 'India', 'was', 'Dr.', 'Rajendra', 'Prasad', 'by', 'the', 'constituent', 'assembly', '.', 'He', 'was', 'a', 'member', 'of', 'the', 'INC', '(', 'Indian', 'National', 'Congress', ')', ',', 'and', 'he', 'was', 'a', 'scholar', '.', 'Mohandas', 'Karamchand', 'Gandhi', ',', 'lovingly', 'known', 'as', 'Bapujii', 'or', 'Mahatma', 'Gandhi', ',', 'is', 'the', 'Father', 'of', 'our', 'Nation', '.', 'He', 'is', 'the', 'most', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'for', 'his', 'contribution', 'to', 'the', 'independence', 'of', 'the', 'country', 'by', 'non-violence', '.', 'Rabindranath', 'Tagore', 'won', 'the', 'Nobel', 'Prize', 'in', 'Literature', 'in', 'the', 'year', '1913', ',', 'and', 'he', 'is', 'one', 'of', 'the', 'most', 'eminent', 'personalities', 'in', 'India', '.']
# ['India', 'secular', 'democracy', '.', 'means', 'religions', 'equally', 'respected', ',', 'every', 'person', 'free', 'follow', 'religion', 'want', '.', 'India', 'largest', 'democracy', 'world', '.', 'People', 'basic', 'human', 'rights', '.', 'national', 'heritage', 'animal', 'India', 'Indian', 'Elephant', '.', 'national', 'river', 'India', 'Ganges', '.', 'Ganges', 'sacred', 'Hindu', 'river', ',', 'sacred', 'believed', 'wash', 'sins', 'people', 'away', '.', 'highest', 'civilian', 'award', 'India', 'Bharat', 'Ratna', ',', 'means', '‘', 'jewel', 'India', '’', '.', 'prominent', 'personalities', 'India', 'serve', 'excellency', 'field', 'work', 'dedication', ',', 'hard', 'work', 'earns', 'award', '.', 'Param', 'Vir', 'Chakra', 'India', '’', 'highest', 'military', 'decoration', 'awarded', 'displaying', 'bravery', '.', 'soldiers', 'life', 'online', 'protect', 'citizens', 'heroes', 'India', '.', 'first', 'prime', 'minister', 'India', 'Pandit', 'Jawaharlal', 'Nehru', ',', 'also', 'called', 'Pandit', 'Nehru', 'Chacha', 'Nehru', '.', 'first', 'President', 'India', 'Dr.', 'Rajendra', 'Prasad', 'constituent', 'assembly', '.', 'member', 'INC', '(', 'Indian', 'National', 'Congress', ')', ',', 'scholar', '.', 'Mohandas', 'Karamchand', 'Gandhi', ',', 'lovingly', 'known', 'Bapujii', 'Mahatma', 'Gandhi', ',', 'Father', 'Nation', '.', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'contribution', 'independence', 'country', 'non-violence', '.', 'Rabindranath', 'Tagore', 'Nobel', 'Prize', 'Literature', 'year', '1913', ',', 'one', 'eminent', 'personalities', 'India', '.', 'India', 'secular', 'democracy', '.', 'This', 'means', 'religions', 'equally', 'respected', ',', 'every', 'person', 'free', 'follow', 'religion', 'want', '.', 'India', 'largest', 'democracy', 'world', '.', 'People', 'basic', 'human', 'rights', '.', 'The', 'national', 'heritage', 'animal', 'India', 'Indian', 'Elephant', '.', 'The', 'national', 'river', 'India', 'Ganges', '.', 'The', 'Ganges', 'sacred', 'Hindu', 'river', ',', 'sacred', 'believed', 'wash', 'sins', 'people', 'away', '.', 'The', 'highest', 'civilian', 'award', 'India', 'Bharat', 'Ratna', ',', 'means', '‘', 'jewel', 'India', '’', '.', 'The', 'prominent', 'personalities', 'India', 'serve', 'excellency', 'field', 'work', 'dedication', ',', 'hard', 'work', 'earns', 'award', '.', 'The', 'Param', 'Vir', 'Chakra', 'India', '’', 'highest', 'military', 'decoration', 'awarded', 'displaying', 'bravery', '.', 'The', 'soldiers', 'life', 'online', 'protect', 'citizens', 'heroes', 'India', '.', 'The', 'first', 'prime', 'minister', 'India', 'Pandit', 'Jawaharlal', 'Nehru', ',', 'also', 'called', 'Pandit', 'Nehru', 'Chacha', 'Nehru', '.', 'The', 'first', 'President', 'India', 'Dr.', 'Rajendra', 'Prasad', 'constituent', 'assembly', '.', 'He', 'member', 'INC', '(', 'Indian', 'National', 'Congress', ')', ',', 'scholar', '.', 'Mohandas', 'Karamchand', 'Gandhi', ',', 'lovingly', 'known', 'Bapujii', 'Mahatma', 'Gandhi', ',', 'Father', 'Nation', '.', 'He', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'contribution', 'independence', 'country', 'non-violence', '.', 'Rabindranath', 'Tagore', 'Nobel', 'Prize', 'Literature', 'year', '1913', ',', 'one', 'eminent', 'personalities', 'India', '.']

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
stemmed_para=[]
for w in word_seg_lower:
    print(w, " : ", porter.stem(w))  #stemming result of word and stemmed word
for w in word_seg_lower:
    stemmed_para.append(w)
print(stemmed_para)
# Out:
# india  :  india
# is  :  is
# a  :  a
# secular  :  secular
# democracy  :  democraci
# .  :  .
# this  :  thi
# means  :  mean
# that  :  that
# all  :  all
# religions  :  religion
# are  :  are
# equally  :  equal
# respected  :  respect
# ,  :  ,
# and  :  and
# every  :  everi
# person  :  person
# is  :  is
# free  :  free
# to  :  to
# follow  :  follow
# any  :  ani
# religion  :  religion
# they  :  they
# want  :  want
# .  :  .
# india  :  india
# is  :  is
# the  :  the
# largest  :  largest
# democracy  :  democraci
# in  :  in
# the  :  the
# world  :  world
# .  :  .
# people  :  peopl
# here  :  here
# have  :  have
# all  :  all
# basic  :  basic
# human  :  human
# rights  :  right
# .  :  .
# the  :  the
# national  :  nation
# heritage  :  heritag
# animal  :  anim
# of  :  of
# india  :  india
# is  :  is
# an  :  an
# indian  :  indian
# elephant  :  eleph
# .  :  .
# the  :  the
# national  :  nation
# river  :  river
# of  :  of
# india  :  india
# is  :  is
# the  :  the
# ganges  :  gang
# .  :  .
# the  :  the
# ganges  :  gang
# is  :  is
# the  :  the
# sacred  :  sacr
# hindu  :  hindu
# river  :  river
# ,  :  ,
# which  :  which
# is  :  is
# so  :  so
# sacred  :  sacr
# that  :  that
# it  :  it
# is  :  is
# believed  :  believ
# to  :  to
# wash  :  wash
# the  :  the
# sins  :  sin
# of  :  of
# people  :  peopl
# away  :  away
# .  :  .
# the  :  the
# highest  :  highest
# civilian  :  civilian
# award  :  award
# in  :  in
# india  :  india
# is  :  is
# the  :  the
# bharat  :  bharat
# ratna  :  ratna
# ,  :  ,
# which  :  which
# means  :  mean
# ‘  :  ‘
# jewel  :  jewel
# of  :  of
# india  :  india
# ’  :  ’
# .  :  .
# the  :  the
# most  :  most
# prominent  :  promin
# personalities  :  person
# of  :  of
# india  :  india
# who  :  who
# serve  :  serv
# with  :  with
# excellency  :  excel
# is  :  is
# their  :  their
# field  :  field
# of  :  of
# work  :  work
# with  :  with
# dedication  :  dedic
# ,  :  ,
# and  :  and
# hard  :  hard
# work  :  work
# earns  :  earn
# this  :  thi
# award  :  award
# .  :  .
# the  :  the
# param  :  param
# vir  :  vir
# chakra  :  chakra
# is  :  is
# india  :  india
# ’  :  ’
# s  :  s
# highest  :  highest
# military  :  militari
# decoration  :  decor
# awarded  :  award
# for  :  for
# displaying  :  display
# bravery  :  braveri
# .  :  .
# the  :  the
# soldiers  :  soldier
# who  :  who
# have  :  have
# their  :  their
# life  :  life
# online  :  onlin
# to  :  to
# protect  :  protect
# the  :  the
# citizens  :  citizen
# are  :  are
# the  :  the
# heroes  :  hero
# of  :  of
# india  :  india
# .  :  .
# the  :  the
# first  :  first
# prime  :  prime
# minister  :  minist
# of  :  of
# india  :  india
# was  :  wa
# pandit  :  pandit
# jawaharlal  :  jawaharl
# nehru  :  nehru
# ,  :  ,
# also  :  also
# called  :  call
# as  :  as
# pandit  :  pandit
# nehru  :  nehru
# or  :  or
# chacha  :  chacha
# nehru  :  nehru
# .  :  .
# the  :  the
# first  :  first
# president  :  presid
# of  :  of
# india  :  india
# was  :  wa
# dr.  :  dr.
# rajendra  :  rajendra
# prasad  :  prasad
# by  :  by
# the  :  the
# constituent  :  constitu
# assembly  :  assembl
# .  :  .
# he  :  he
# was  :  wa
# a  :  a
# member  :  member
# of  :  of
# the  :  the
# inc  :  inc
# (  :  (
# indian  :  indian
# national  :  nation
# congress  :  congress
# )  :  )
# ,  :  ,
# and  :  and
# he  :  he
# was  :  wa
# a  :  a
# scholar  :  scholar
# .  :  .
# mohandas  :  mohanda
# karamchand  :  karamchand
# gandhi  :  gandhi
# ,  :  ,
# lovingly  :  lovingli
# known  :  known
# as  :  as
# bapujii  :  bapujii
# or  :  or
# mahatma  :  mahatma
# gandhi  :  gandhi
# ,  :  ,
# is  :  is
# the  :  the
# father  :  father
# of  :  of
# our  :  our
# nation  :  nation
# .  :  .
# he  :  he
# is  :  is
# the  :  the
# most  :  most
# recognized  :  recogn
# figure  :  figur
# worldwide  :  worldwid
# ,  :  ,
# best  :  best
# known  :  known
# for  :  for
# his  :  hi
# contribution  :  contribut
# to  :  to
# the  :  the
# independence  :  independ
# of  :  of
# the  :  the
# country  :  countri
# by  :  by
# non-violence  :  non-viol
# .  :  .
# rabindranath  :  rabindranath
# tagore  :  tagor
# won  :  won
# the  :  the
# nobel  :  nobel
# prize  :  prize
# in  :  in
# literature  :  literatur
# in  :  in
# the  :  the
# year  :  year
# 1913  :  1913
# ,  :  ,
# and  :  and
# he  :  he
# is  :  is
# one  :  one
# of  :  of
# the  :  the
# most  :  most
# eminent  :  emin
# personalities  :  person
# in  :  in
# india  :  india
# .  :  .
# ['india', 'is', 'a', 'secular', 'democracy', '.', 'this', 'means', 'that', 'all', 'religions', 'are', 'equally', 'respected', ',', 'and', 'every', 'person', 'is', 'free', 'to', 'follow', 'any', 'religion', 'they', 'want', '.', 'india', 'is', 'the', 'largest', 'democracy', 'in', 'the', 'world', '.', 'people', 'here', 'have', 'all', 'basic', 'human', 'rights', '.', 'the', 'national', 'heritage', 'animal', 'of', 'india', 'is', 'an', 'indian', 'elephant', '.', 'the', 'national', 'river', 'of', 'india', 'is', 'the', 'ganges', '.', 'the', 'ganges', 'is', 'the', 'sacred', 'hindu', 'river', ',', 'which', 'is', 'so', 'sacred', 'that', 'it', 'is', 'believed', 'to', 'wash', 'the', 'sins', 'of', 'people', 'away', '.', 'the', 'highest', 'civilian', 'award', 'in', 'india', 'is', 'the', 'bharat', 'ratna', ',', 'which', 'means', '‘', 'jewel', 'of', 'india', '’', '.', 'the', 'most', 'prominent', 'personalities', 'of', 'india', 'who', 'serve', 'with', 'excellency', 'is', 'their', 'field', 'of', 'work', 'with', 'dedication', ',', 'and', 'hard', 'work', 'earns', 'this', 'award', '.', 'the', 'param', 'vir', 'chakra', 'is', 'india', '’', 's', 'highest', 'military', 'decoration', 'awarded', 'for', 'displaying', 'bravery', '.', 'the', 'soldiers', 'who', 'have', 'their', 'life', 'online', 'to', 'protect', 'the', 'citizens', 'are', 'the', 'heroes', 'of', 'india', '.', 'the', 'first', 'prime', 'minister', 'of', 'india', 'was', 'pandit', 'jawaharlal', 'nehru', ',', 'also', 'called', 'as', 'pandit', 'nehru', 'or', 'chacha', 'nehru', '.', 'the', 'first', 'president', 'of', 'india', 'was', 'dr.', 'rajendra', 'prasad', 'by', 'the', 'constituent', 'assembly', '.', 'he', 'was', 'a', 'member', 'of', 'the', 'inc', '(', 'indian', 'national', 'congress', ')', ',', 'and', 'he', 'was', 'a', 'scholar', '.', 'mohandas', 'karamchand', 'gandhi', ',', 'lovingly', 'known', 'as', 'bapujii', 'or', 'mahatma', 'gandhi', ',', 'is', 'the', 'father', 'of', 'our', 'nation', '.', 'he', 'is', 'the', 'most', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'for', 'his', 'contribution', 'to', 'the', 'independence', 'of', 'the', 'country', 'by', 'non-violence', '.', 'rabindranath', 'tagore', 'won', 'the', 'nobel', 'prize', 'in', 'literature', 'in', 'the', 'year', '1913', ',', 'and', 'he', 'is', 'one', 'of', 'the', 'most', 'eminent', 'personalities', 'in', 'india', '.']

# %% [markdown]
# Lemmatization

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\shyle_dwx0bd9\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
lemmed_para=[]
for w in word_seg_lower:
    print(w, " : ", lem.lemmatize(w))
for w in word_seg_lower:
    lemmed_para.append(w)
print(lemmed_para)
# Out:
# india  :  india
# is  :  is
# a  :  a
# secular  :  secular
# democracy  :  democracy
# .  :  .
# this  :  this
# means  :  mean
# that  :  that
# all  :  all
# religions  :  religion
# are  :  are
# equally  :  equally
# respected  :  respected
# ,  :  ,
# and  :  and
# every  :  every
# person  :  person
# is  :  is
# free  :  free
# to  :  to
# follow  :  follow
# any  :  any
# religion  :  religion
# they  :  they
# want  :  want
# .  :  .
# india  :  india
# is  :  is
# the  :  the
# largest  :  largest
# democracy  :  democracy
# in  :  in
# the  :  the
# world  :  world
# .  :  .
# people  :  people
# here  :  here
# have  :  have
# all  :  all
# basic  :  basic
# human  :  human
# rights  :  right
# .  :  .
# the  :  the
# national  :  national
# heritage  :  heritage
# animal  :  animal
# of  :  of
# india  :  india
# is  :  is
# an  :  an
# indian  :  indian
# elephant  :  elephant
# .  :  .
# the  :  the
# national  :  national
# river  :  river
# of  :  of
# india  :  india
# is  :  is
# the  :  the
# ganges  :  ganges
# .  :  .
# the  :  the
# ganges  :  ganges
# is  :  is
# the  :  the
# sacred  :  sacred
# hindu  :  hindu
# river  :  river
# ,  :  ,
# which  :  which
# is  :  is
# so  :  so
# sacred  :  sacred
# that  :  that
# it  :  it
# is  :  is
# believed  :  believed
# to  :  to
# wash  :  wash
# the  :  the
# sins  :  sin
# of  :  of
# people  :  people
# away  :  away
# .  :  .
# the  :  the
# highest  :  highest
# civilian  :  civilian
# award  :  award
# in  :  in
# india  :  india
# is  :  is
# the  :  the
# bharat  :  bharat
# ratna  :  ratna
# ,  :  ,
# which  :  which
# means  :  mean
# ‘  :  ‘
# jewel  :  jewel
# of  :  of
# india  :  india
# ’  :  ’
# .  :  .
# the  :  the
# most  :  most
# prominent  :  prominent
# personalities  :  personality
# of  :  of
# india  :  india
# who  :  who
# serve  :  serve
# with  :  with
# excellency  :  excellency
# is  :  is
# their  :  their
# field  :  field
# of  :  of
# work  :  work
# with  :  with
# dedication  :  dedication
# ,  :  ,
# and  :  and
# hard  :  hard
# work  :  work
# earns  :  earns
# this  :  this
# award  :  award
# .  :  .
# the  :  the
# param  :  param
# vir  :  vir
# chakra  :  chakra
# is  :  is
# india  :  india
# ’  :  ’
# s  :  s
# highest  :  highest
# military  :  military
# decoration  :  decoration
# awarded  :  awarded
# for  :  for
# displaying  :  displaying
# bravery  :  bravery
# .  :  .
# the  :  the
# soldiers  :  soldier
# who  :  who
# have  :  have
# their  :  their
# life  :  life
# online  :  online
# to  :  to
# protect  :  protect
# the  :  the
# citizens  :  citizen
# are  :  are
# the  :  the
# heroes  :  hero
# of  :  of
# india  :  india
# .  :  .
# the  :  the
# first  :  first
# prime  :  prime
# minister  :  minister
# of  :  of
# india  :  india
# was  :  wa
# pandit  :  pandit
# jawaharlal  :  jawaharlal
# nehru  :  nehru
# ,  :  ,
# also  :  also
# called  :  called
# as  :  a
# pandit  :  pandit
# nehru  :  nehru
# or  :  or
# chacha  :  chacha
# nehru  :  nehru
# .  :  .
# the  :  the
# first  :  first
# president  :  president
# of  :  of
# india  :  india
# was  :  wa
# dr.  :  dr.
# rajendra  :  rajendra
# prasad  :  prasad
# by  :  by
# the  :  the
# constituent  :  constituent
# assembly  :  assembly
# .  :  .
# he  :  he
# was  :  wa
# a  :  a
# member  :  member
# of  :  of
# the  :  the
# inc  :  inc
# (  :  (
# indian  :  indian
# national  :  national
# congress  :  congress
# )  :  )
# ,  :  ,
# and  :  and
# he  :  he
# was  :  wa
# a  :  a
# scholar  :  scholar
# .  :  .
# mohandas  :  mohandas
# karamchand  :  karamchand
# gandhi  :  gandhi
# ,  :  ,
# lovingly  :  lovingly
# known  :  known
# as  :  a
# bapujii  :  bapujii
# or  :  or
# mahatma  :  mahatma
# gandhi  :  gandhi
# ,  :  ,
# is  :  is
# the  :  the
# father  :  father
# of  :  of
# our  :  our
# nation  :  nation
# .  :  .
# he  :  he
# is  :  is
# the  :  the
# most  :  most
# recognized  :  recognized
# figure  :  figure
# worldwide  :  worldwide
# ,  :  ,
# best  :  best
# known  :  known
# for  :  for
# his  :  his
# contribution  :  contribution
# to  :  to
# the  :  the
# independence  :  independence
# of  :  of
# the  :  the
# country  :  country
# by  :  by
# non-violence  :  non-violence
# .  :  .
# rabindranath  :  rabindranath
# tagore  :  tagore
# won  :  won
# the  :  the
# nobel  :  nobel
# prize  :  prize
# in  :  in
# literature  :  literature
# in  :  in
# the  :  the
# year  :  year
# 1913  :  1913
# ,  :  ,
# and  :  and
# he  :  he
# is  :  is
# one  :  one
# of  :  of
# the  :  the
# most  :  most
# eminent  :  eminent
# personalities  :  personality
# in  :  in
# india  :  india
# .  :  .
# ['india', 'is', 'a', 'secular', 'democracy', '.', 'this', 'means', 'that', 'all', 'religions', 'are', 'equally', 'respected', ',', 'and', 'every', 'person', 'is', 'free', 'to', 'follow', 'any', 'religion', 'they', 'want', '.', 'india', 'is', 'the', 'largest', 'democracy', 'in', 'the', 'world', '.', 'people', 'here', 'have', 'all', 'basic', 'human', 'rights', '.', 'the', 'national', 'heritage', 'animal', 'of', 'india', 'is', 'an', 'indian', 'elephant', '.', 'the', 'national', 'river', 'of', 'india', 'is', 'the', 'ganges', '.', 'the', 'ganges', 'is', 'the', 'sacred', 'hindu', 'river', ',', 'which', 'is', 'so', 'sacred', 'that', 'it', 'is', 'believed', 'to', 'wash', 'the', 'sins', 'of', 'people', 'away', '.', 'the', 'highest', 'civilian', 'award', 'in', 'india', 'is', 'the', 'bharat', 'ratna', ',', 'which', 'means', '‘', 'jewel', 'of', 'india', '’', '.', 'the', 'most', 'prominent', 'personalities', 'of', 'india', 'who', 'serve', 'with', 'excellency', 'is', 'their', 'field', 'of', 'work', 'with', 'dedication', ',', 'and', 'hard', 'work', 'earns', 'this', 'award', '.', 'the', 'param', 'vir', 'chakra', 'is', 'india', '’', 's', 'highest', 'military', 'decoration', 'awarded', 'for', 'displaying', 'bravery', '.', 'the', 'soldiers', 'who', 'have', 'their', 'life', 'online', 'to', 'protect', 'the', 'citizens', 'are', 'the', 'heroes', 'of', 'india', '.', 'the', 'first', 'prime', 'minister', 'of', 'india', 'was', 'pandit', 'jawaharlal', 'nehru', ',', 'also', 'called', 'as', 'pandit', 'nehru', 'or', 'chacha', 'nehru', '.', 'the', 'first', 'president', 'of', 'india', 'was', 'dr.', 'rajendra', 'prasad', 'by', 'the', 'constituent', 'assembly', '.', 'he', 'was', 'a', 'member', 'of', 'the', 'inc', '(', 'indian', 'national', 'congress', ')', ',', 'and', 'he', 'was', 'a', 'scholar', '.', 'mohandas', 'karamchand', 'gandhi', ',', 'lovingly', 'known', 'as', 'bapujii', 'or', 'mahatma', 'gandhi', ',', 'is', 'the', 'father', 'of', 'our', 'nation', '.', 'he', 'is', 'the', 'most', 'recognized', 'figure', 'worldwide', ',', 'best', 'known', 'for', 'his', 'contribution', 'to', 'the', 'independence', 'of', 'the', 'country', 'by', 'non-violence', '.', 'rabindranath', 'tagore', 'won', 'the', 'nobel', 'prize', 'in', 'literature', 'in', 'the', 'year', '1913', ',', 'and', 'he', 'is', 'one', 'of', 'the', 'most', 'eminent', 'personalities', 'in', 'india', '.']

# %% [markdown]
# tagger for part of speech

# %%
tagged = nltk.pos_tag(word_seg_lower)
print(tagged)
#we can remove the stopwords for tagging if we want
para_wo = nltk.pos_tag(para_wo_sw)
print(para_wo)
# Out:
# [('india', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('secular', 'JJ'), ('democracy', 'NN'), ('.', '.'), ('this', 'DT'), ('means', 'VBZ'), ('that', 'IN'), ('all', 'DT'), ('religions', 'NNS'), ('are', 'VBP'), ('equally', 'RB'), ('respected', 'VBN'), (',', ','), ('and', 'CC'), ('every', 'DT'), ('person', 'NN'), ('is', 'VBZ'), ('free', 'JJ'), ('to', 'TO'), ('follow', 'VB'), ('any', 'DT'), ('religion', 'NN'), ('they', 'PRP'), ('want', 'VBP'), ('.', '.'), ('india', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('largest', 'JJS'), ('democracy', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('people', 'NNS'), ('here', 'RB'), ('have', 'VBP'), ('all', 'DT'), ('basic', 'JJ'), ('human', 'JJ'), ('rights', 'NNS'), ('.', '.'), ('the', 'DT'), ('national', 'JJ'), ('heritage', 'NN'), ('animal', 'NN'), ('of', 'IN'), ('india', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('indian', 'JJ'), ('elephant', 'NN'), ('.', '.'), ('the', 'DT'), ('national', 'JJ'), ('river', 'NN'), ('of', 'IN'), ('india', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('ganges', 'NNS'), ('.', '.'), ('the', 'DT'), ('ganges', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('sacred', 'JJ'), ('hindu', 'NN'), ('river', 'NN'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('so', 'RB'), ('sacred', 'JJ'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('believed', 'VBN'), ('to', 'TO'), ('wash', 'VB'), ('the', 'DT'), ('sins', 'NNS'), ('of', 'IN'), ('people', 'NNS'), ('away', 'RB'), ('.', '.'), ('the', 'DT'), ('highest', 'JJS'), ('civilian', 'JJ'), ('award', 'NN'), ('in', 'IN'), ('india', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('bharat', 'NN'), ('ratna', 'NN'), (',', ','), ('which', 'WDT'), ('means', 'VBZ'), ('‘', 'JJ'), ('jewel', 'NN'), ('of', 'IN'), ('india', 'JJ'), ('’', 'NNP'), ('.', '.'), ('the', 'DT'), ('most', 'RBS'), ('prominent', 'JJ'), ('personalities', 'NNS'), ('of', 'IN'), ('india', 'NN'), ('who', 'WP'), ('serve', 'VBP'), ('with', 'IN'), ('excellency', 'NN'), ('is', 'VBZ'), ('their', 'PRP$'), ('field', 'NN'), ('of', 'IN'), ('work', 'NN'), ('with', 'IN'), ('dedication', 'NN'), (',', ','), ('and', 'CC'), ('hard', 'JJ'), ('work', 'NN'), ('earns', 'VBZ'), ('this', 'DT'), ('award', 'NN'), ('.', '.'), ('the', 'DT'), ('param', 'NN'), ('vir', 'NN'), ('chakra', 'NN'), ('is', 'VBZ'), ('india', 'JJ'), ('’', 'NNP'), ('s', 'NN'), ('highest', 'JJS'), ('military', 'JJ'), ('decoration', 'NN'), ('awarded', 'VBD'), ('for', 'IN'), ('displaying', 'VBG'), ('bravery', 'NN'), ('.', '.'), ('the', 'DT'), ('soldiers', 'NNS'), ('who', 'WP'), ('have', 'VBP'), ('their', 'PRP$'), ('life', 'NN'), ('online', 'NN'), ('to', 'TO'), ('protect', 'VB'), ('the', 'DT'), ('citizens', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('heroes', 'NNS'), ('of', 'IN'), ('india', 'NN'), ('.', '.'), ('the', 'DT'), ('first', 'JJ'), ('prime', 'JJ'), ('minister', 'NN'), ('of', 'IN'), ('india', 'NN'), ('was', 'VBD'), ('pandit', 'JJ'), ('jawaharlal', 'NN'), ('nehru', 'NN'), (',', ','), ('also', 'RB'), ('called', 'VBD'), ('as', 'IN'), ('pandit', 'NN'), ('nehru', 'NN'), ('or', 'CC'), ('chacha', 'NN'), ('nehru', 'NN'), ('.', '.'), ('the', 'DT'), ('first', 'JJ'), ('president', 'NN'), ('of', 'IN'), ('india', 'NN'), ('was', 'VBD'), ('dr.', 'JJ'), ('rajendra', 'NN'), ('prasad', 'NN'), ('by', 'IN'), ('the', 'DT'), ('constituent', 'NN'), ('assembly', 'RB'), ('.', '.'), ('he', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('member', 'NN'), ('of', 'IN'), ('the', 'DT'), ('inc', 'NN'), ('(', '('), ('indian', 'JJ'), ('national', 'JJ'), ('congress', 'NN'), (')', ')'), (',', ','), ('and', 'CC'), ('he', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('scholar', 'NN'), ('.', '.'), ('mohandas', 'NNS'), ('karamchand', 'VBP'), ('gandhi', 'NN'), (',', ','), ('lovingly', 'RB'), ('known', 'VBN'), ('as', 'IN'), ('bapujii', 'NN'), ('or', 'CC'), ('mahatma', 'NN'), ('gandhi', 'NN'), (',', ','), ('is', 'VBZ'), ('the', 'DT'), ('father', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('nation', 'NN'), ('.', '.'), ('he', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('most', 'RBS'), ('recognized', 'JJ'), ('figure', 'NN'), ('wor ...
# [('India', 'NNP'), ('secular', 'JJ'), ('democracy', 'NN'), ('.', '.'), ('means', 'VBZ'), ('religions', 'NNS'), ('equally', 'RB'), ('respected', 'VBD'), (',', ','), ('every', 'DT'), ('person', 'NN'), ('free', 'JJ'), ('follow', 'VBP'), ('religion', 'NN'), ('want', 'NN'), ('.', '.'), ('India', 'NNP'), ('largest', 'JJS'), ('democracy', 'NN'), ('world', 'NN'), ('.', '.'), ('People', 'NNS'), ('basic', 'JJ'), ('human', 'JJ'), ('rights', 'NNS'), ('.', '.'), ('national', 'JJ'), ('heritage', 'NN'), ('animal', 'JJ'), ('India', 'NNP'), ('Indian', 'NNP'), ('Elephant', 'NNP'), ('.', '.'), ('national', 'JJ'), ('river', 'NN'), ('India', 'NNP'), ('Ganges', 'NNP'), ('.', '.'), ('Ganges', 'NNP'), ('sacred', 'VBD'), ('Hindu', 'NNP'), ('river', 'NN'), (',', ','), ('sacred', 'VBD'), ('believed', 'VBN'), ('wash', 'JJ'), ('sins', 'NNS'), ('people', 'NNS'), ('away', 'RB'), ('.', '.'), ('highest', 'JJS'), ('civilian', 'JJ'), ('award', 'NN'), ('India', 'NNP'), ('Bharat', 'NNP'), ('Ratna', 'NNP'), (',', ','), ('means', 'VBZ'), ('‘', 'JJ'), ('jewel', 'NN'), ('India', 'NNP'), ('’', 'NNP'), ('.', '.'), ('prominent', 'JJ'), ('personalities', 'NNS'), ('India', 'NNP'), ('serve', 'VBP'), ('excellency', 'NN'), ('field', 'NN'), ('work', 'NN'), ('dedication', 'NN'), (',', ','), ('hard', 'JJ'), ('work', 'NN'), ('earns', 'VBZ'), ('award', 'RB'), ('.', '.'), ('Param', 'NNP'), ('Vir', 'NNP'), ('Chakra', 'NNP'), ('India', 'NNP'), ('’', 'NNP'), ('highest', 'JJS'), ('military', 'JJ'), ('decoration', 'NN'), ('awarded', 'VBD'), ('displaying', 'VBG'), ('bravery', 'NN'), ('.', '.'), ('soldiers', 'NNS'), ('life', 'NN'), ('online', 'VBP'), ('protect', 'NN'), ('citizens', 'NNS'), ('heroes', 'NNS'), ('India', 'NNP'), ('.', '.'), ('first', 'JJ'), ('prime', 'JJ'), ('minister', 'NN'), ('India', 'NNP'), ('Pandit', 'NNP'), ('Jawaharlal', 'NNP'), ('Nehru', 'NNP'), (',', ','), ('also', 'RB'), ('called', 'VBD'), ('Pandit', 'NNP'), ('Nehru', 'NNP'), ('Chacha', 'NNP'), ('Nehru', 'NNP'), ('.', '.'), ('first', 'JJ'), ('President', 'NNP'), ('India', 'NNP'), ('Dr.', 'NNP'), ('Rajendra', 'NNP'), ('Prasad', 'NNP'), ('constituent', 'NN'), ('assembly', 'NN'), ('.', '.'), ('member', 'NN'), ('INC', 'NNP'), ('(', '('), ('Indian', 'JJ'), ('National', 'NNP'), ('Congress', 'NNP'), (')', ')'), (',', ','), ('scholar', 'JJ'), ('.', '.'), ('Mohandas', 'NNP'), ('Karamchand', 'NNP'), ('Gandhi', 'NNP'), (',', ','), ('lovingly', 'RB'), ('known', 'VBN'), ('Bapujii', 'NNP'), ('Mahatma', 'NNP'), ('Gandhi', 'NNP'), (',', ','), ('Father', 'NNP'), ('Nation', 'NNP'), ('.', '.'), ('recognized', 'VBN'), ('figure', 'NN'), ('worldwide', 'NN'), (',', ','), ('best', 'RB'), ('known', 'VBN'), ('contribution', 'NN'), ('independence', 'NN'), ('country', 'NN'), ('non-violence', 'NN'), ('.', '.'), ('Rabindranath', 'NNP'), ('Tagore', 'NNP'), ('Nobel', 'NNP'), ('Prize', 'NNP'), ('Literature', 'NNP'), ('year', 'NN'), ('1913', 'CD'), (',', ','), ('one', 'CD'), ('eminent', 'NN'), ('personalities', 'NNS'), ('India', 'NNP'), ('.', '.'), ('India', 'NNP'), ('secular', 'JJ'), ('democracy', 'NN'), ('.', '.'), ('This', 'DT'), ('means', 'VBZ'), ('religions', 'NNS'), ('equally', 'RB'), ('respected', 'VBD'), (',', ','), ('every', 'DT'), ('person', 'NN'), ('free', 'JJ'), ('follow', 'VBP'), ('religion', 'NN'), ('want', 'NN'), ('.', '.'), ('India', 'NNP'), ('largest', 'JJS'), ('democracy', 'NN'), ('world', 'NN'), ('.', '.'), ('People', 'NNS'), ('basic', 'JJ'), ('human', 'JJ'), ('rights', 'NNS'), ('.', '.'), ('The', 'DT'), ('national', 'JJ'), ('heritage', 'NN'), ('animal', 'JJ'), ('India', 'NNP'), ('Indian', 'NNP'), ('Elephant', 'NNP'), ('.', '.'), ('The', 'DT'), ('national', 'JJ'), ('river', 'NN'), ('India', 'NNP'), ('Ganges', 'NNP'), ('.', '.'), ('The', 'DT'), ('Ganges', 'NNPS'), ('sacred', 'VBD'), ('Hindu', 'NNP'), ('river', 'NN'), (',', ','), ('sacred', 'VBD'), ('believed', 'VBN'), ('wash', 'JJ'), ('sins', 'NNS'), ('people', 'NNS'), ('away', 'RB'), ('.', '.'), ('The', 'DT'), ('highest', 'JJS'), ('civilian', 'JJ'), ('award', 'NN'), ('India', 'N ...
